# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
SP_all_daily = pd.read_csv('SP_all_daily.csv')
#SP_all_daily = SP_all_daily.sort_values('Date', ascending=True, ignore_index=True)
SP_all_daily = SP_all_daily.set_index('Date')
SP_all_daily
# Out:
#             S&P_Open  S&P_Close    S&P_Volume  Close_t-1  return(%)  \
# Date
# 2022-09-02   3994.66    3924.26  4.134920e+09    3966.85  -1.073648
# 2022-09-01   3936.73    3966.85  3.754570e+09    3955.00   0.299621
# 2022-08-31   4000.67    3955.00  3.797860e+09    3986.16  -0.781705
# 2022-08-30   4041.25    3986.16  3.190580e+09    4030.61  -1.102811
# 2022-08-29   4034.58    4030.61  2.963020e+09    4057.66  -0.666640
# ...              ...        ...           ...        ...        ...
# 1928-01-06     17.66      17.66  1.260000e+06      17.55   0.626781
# 1928-01-05     17.55      17.55  1.260000e+06      17.72  -0.959368
# 1928-01-04     17.72      17.72  1.260000e+06      17.76  -0.225225
# 1928-01-03     17.76      17.76  1.260000e+06      17.66   0.566251
# 1927-12-30     17.66      17.66  1.260000e+06        NaN        NaN
#
#             return_class  Close_t+1  t+1_return_class  t_3m_Close  \
# Date
# 2022-09-02             0        NaN               NaN       2.860
# 2022-09-01             1    3924.26               0.0       2.860
# 2022-08-31             0    3966.85               1.0       2.860
# 2022-08-30             0    3955.00               0.0       2.873
# 2022-08-29             0    3986.16               0.0       2.798
# ...                  ...        ...               ...         ...
# 1928-01-06             2      17.50               0.0       4.520
# 1928-01-05             0      17.66               2.0       4.520
# 1928-01-04             1      17.55               0.0       4.520
# 1928-01-03             2      17.72               1.0       4.520
# 1927-12-30             0      17.76               2.0       4.520
#
#             t_10y_Close  ...      Nk_Close   Nk_Volume  fx_Price  fx_change%  \
# Date                     ...
# 2022-09-02        3.133  ...  27650.839844  58800000.0    1.3132       -0.15
# 2022-09-01        3.133  ...  27661.470703  68900000.0    1.3152        0.19
# 2022-08-31        3.133  ...  28091.529297  86200000.0    1.3127        0.27
# 2022-08-30        3.110  ...  28195.580078  60700000.0    1.3092        0.62
# 2022-08-29        3.110  ...  27878.960938  64100000.0    1.3011       -0.17
# ...                 ...  ...           ...         ...       ...         ...
# 1928-01-06        4.060  ...   1257.719971         0.0    1.1895        0.24
# 1928-01-05        4.060  ...   1257.719971         0.0    1.1895        0.24
# 1928-01-04        4.060  ...   1257.719971         0.0    1.1895        0.24
# 1928-01-03        4.060  ...   1257.719971         0.0    1.1895        0.24
# 1927-12-30        4.060  ...   1257.719971         0.0    1.1895        0.24
#
#               vo_Open   vo_Close  Year  Month  Day  Dayofweek
# Date
# 2022-09-02  25.510000  25.469999  2022      9    2          4
# 2022-09-01  26.879999  25.559999  2022      9    1          3
# 2022-08-31  25.860001  25.870001  2022      8   31          2
# 2022-08-30  25.750000  26.209999  2022      8   30          1
# 2022-08-29  26.860001  26.209999  2022      8   29          0
# ...               ...        ...   ...    ...  ...        ...
# 1928-01-06  17.240000  17.240000  1928      1    6          4
# 1928-01-05  17.240000  17.240000  1928      1    5          3
# 1928-01-04  17.240000  17.240000  1928      1    4          2
# 1928-01-03  17.240000  17.240000  1928      1    3          1
# 1927-12-30  17.240000  17.240000  1927     12   30          4
#
# [23783 rows x 42 columns]

# %%
def MovingAverage(days):
    total = 0
    for day in range(days):
        total+= SP_all_daily['S&P_Close'].shift(-day)
    return round(total/days,2)

# %%
SP_all_daily['MA30'] = MovingAverage(30)
SP_all_daily['MA50'] = MovingAverage(50)
SP_all_daily['MA200'] = MovingAverage(200)

# %%
SP_all_daily = SP_all_daily.dropna() 
SP_all_daily.head()
# Out:
#             S&P_Open  S&P_Close    S&P_Volume  Close_t-1  return(%)  \
# Date
# 2022-09-01   3936.73    3966.85  3.754570e+09    3955.00   0.299621
# 2022-08-31   4000.67    3955.00  3.797860e+09    3986.16  -0.781705
# 2022-08-30   4041.25    3986.16  3.190580e+09    4030.61  -1.102811
# 2022-08-29   4034.58    4030.61  2.963020e+09    4057.66  -0.666640
# 2022-08-26   4198.74    4057.66  3.175260e+09    4199.12  -3.368801
#
#             return_class  Close_t+1  t+1_return_class  t_3m_Close  \
# Date
# 2022-09-01             1    3924.26               0.0       2.860
# 2022-08-31             0    3966.85               1.0       2.860
# 2022-08-30             0    3955.00               0.0       2.873
# 2022-08-29             0    3986.16               0.0       2.798
# 2022-08-26             0    4030.61               0.0       2.755
#
#             t_10y_Close  ...  fx_change%    vo_Open   vo_Close  Year  Month  \
# Date                     ...
# 2022-09-01        3.133  ...        0.19  26.879999  25.559999  2022      9
# 2022-08-31        3.133  ...        0.27  25.860001  25.870001  2022      8
# 2022-08-30        3.110  ...        0.62  25.750000  26.209999  2022      8
# 2022-08-29        3.110  ...       -0.17  26.860001  26.209999  2022      8
# 2022-08-26        3.035  ...        0.84  22.070000  25.559999  2022      8
#
#             Day  Dayofweek     MA30     MA50    MA200
# Date
# 2022-09-01    1          3  4122.99  4017.63  4293.44
# 2022-08-31   31          2  4124.06  4013.50  4297.02
# 2022-08-30   30          1  4124.22  4009.69  4300.66
# 2022-08-29   29          0  4122.57  4003.46  4303.97
# 2022-08-26   26          4  4115.91  3996.19  4307.05
#
# [5 rows x 45 columns]

# %%
SP_all_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23583 entries, 1928-01-03 to 2021-11-17
# Data columns (total 45 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   S&P_Open          23583 non-null  float64
#  1   S&P_Close         23583 non-null  float64
#  2   S&P_Volume        23583 non-null  float64
#  3   Close_t-1         23583 non-null  float64
#  4   return(%)         23583 non-null  float64
#  5   return_class      23583 non-null  int64
#  6   Close_t+1         23583 non-null  float64
#  7   t+1_return_class  23583 non-null  float64
#  8   t_3m_Close        23583 non-null  float64
#  9   t_10y_Close       23583 non-null  float64
#  10  cpi_Value         23583 non-null  float64
#  11  cpi_MoM%          23583 non-null  float64
#  12  oil_Price         23583 non-null  float64
#  13  unemp_rate        23583 non-null  float64
#  14  PE_Ratio          23583 non-null  float64
#  15  Div_Ratio         23583 non-null  float64
#  16  EY_Ratio          23583 non-null  float64
#  17  CS_Index          23583 non-null  float64
#  18  Put/Call_Ratio    23583 non-null  float64
#  19  R_Open            23583 non-null  float64
#  20  R_Close           23583 non-null  float64
#  21  R_Volume          23583 non-null  float64
#  22  G_Open            23583 non-null  float64
#  23  G_Close           23583 non-null  float64
#  24  G_Volume          23583 non-null  float64
#  25  GF_Open           23583 non-null  float64
#  26  GF_Close          23583 non-null  float64
#  27  GF_Volume         23583 non-null  float64
#  28  Nas_Open          23583 non-null  float64
#  29  Nas_Close         23583 non-null  float64
#  30  Nas_Volume        23583 non-null  float64
#  31  Nk_Open           23583 non-null  float64
#  32  Nk_Close          23583 non-null  float64
#  33  Nk_Volume         23583 non-null  float64
#  34  fx_Price          23583 non-null  float64
#  35  fx_change%        23583 non-null  float64
#  36  vo_Open           23583 non-null  float64
#  37  vo_Close          23583 non-null  float64
#  38  Year              23583 non-null  int64
#  39  Month             23583 non-null  int64
#  40  Day               23583 non-null  int64
#  41  Dayofweek         23583 non-null  int64
#  42  MA30              23583 non-null  float64
#  43  MA50              23583 non-null  float64
#  44  MA200             23583 non-null  float64
# dtypes: float64(40), int64(5)
# memory usage: 8.3+ MB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Let's try with only after 1986 data 
SP_all_daily = SP_all_daily[SP_all_daily.index >= '1986-01-01']

# %%
plt.hist(SP_all_daily['return(%)'], bins = 50)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00,
#         2.000e+00, 1.000e+00, 2.000e+00, 5.000e+00, 6.000e+00, 5.000e+00,
#         1.100e+01, 2.300e+01, 3.700e+01, 9.100e+01, 1.990e+02, 4.590e+02,
#         1.045e+03, 2.628e+03, 2.745e+03, 1.208e+03, 4.630e+02, 1.710e+02,
#         5.500e+01, 3.200e+01, 2.100e+01, 1.300e+01, 4.000e+00, 4.000e+00,
#         4.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 3.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00]),
#  array([-20.46692607, -19.82598683, -19.18504759, -18.54410834,
#         -17.9031691 , -17.26222986, -16.62129062, -15.98035138,
#         -15.33941213, -14.69847289, -14.05753365, -13.41659441,
#         -12.77565517, -12.13471592, -11.49377668, -10.85283744,
#         -10.2118982 ,  -9.57095896,  -8.93001971,  -8.28908047,
#          -7.64814123,  -7.00720199,  -6.36626275,  -5.7253235 ,
#          -5.08438426,  -4.44344502,  -3.80250578,  -3.16156654,
#          -2.52062729,  -1.87968805,  -1.23874881,  -0.59780957,
#           0.04312967,   0.68406892,   1.32500816,   1.9659474 ,
#           2.60688664,   3.24782588,   3.88876513,   4.52970437,
#           5.17064361,   5.81158285,   6.4525221 ,   7.09346134,
#           7.73440058,   8.37533982,   9.01627906,   9.65721831,
#          10.29815755,  10.93909679,  11.58003603]),
#  <BarContainer object of 50 artists>)

# %%
SP_all_daily.loc[SP_all_daily['return(%)'] <= -10]
# Out:
#             S&P_Open  S&P_Close    S&P_Volume  Close_t-1  return(%)  \
# Date
# 2020-03-16   2508.59    2386.13  7.781540e+09    2711.02 -11.984050
# 1987-10-19    282.70     224.84  6.043000e+08     282.70 -20.466926
#
#             return_class  Close_t+1  t+1_return_class  t_3m_Close  \
# Date
# 2020-03-16             0    2529.19               2.0       0.185
# 1987-10-19             0     236.83               2.0       6.390
#
#             t_10y_Close  ...  fx_change%    vo_Open   vo_Close  Year  Month  \
# Date                     ...
# 2020-03-16        0.728  ...        1.54  57.830002  82.690002  2020      3
# 1987-10-19       10.150  ...        0.32  17.240000  17.240000  1987     10
#
#             Day  Dayofweek     MA30     MA50    MA200
# Date
# 2020-03-16   16          0  3114.57  3180.43  3047.16
# 1987-10-19   19          0   313.04   319.85   298.64
#
# [2 rows x 45 columns]

# %% [markdown]
# 1987 Oct - Black Monday
# 1998 Aug - Russian Financial crisis
# 2002 Sep - .com bubble burst
# 2008 Oct/2009 Feb - US Financial crisis
# 2020 Mar - Covid
# There is always a market crash at some point after rapid recovery from recessions

# %%
SP_all_daily.loc[SP_all_daily['return(%)'] >= 10]
# Out:
#             S&P_Open  S&P_Close    S&P_Volume  Close_t-1  return(%)  \
# Date
# 2008-10-28    848.92     940.51  7.096950e+09     848.92  10.789002
# 2008-10-13    912.75    1003.35  7.263370e+09     899.22  11.580036
#
#             return_class  Close_t+1  t+1_return_class  t_3m_Close  \
# Date
# 2008-10-28             2     930.09               0.0        0.75
# 2008-10-13             2     998.01               0.0        0.21
#
#             t_10y_Close  ...  fx_change%    vo_Open   vo_Close  Year  Month  \
# Date                     ...
# 2008-10-28        3.820  ...       -1.88  73.300003  66.959999  2008     10
# 2008-10-13        3.861  ...       -2.30  69.949997  54.990002  2008     10
#
#             Day  Dayofweek     MA30     MA50    MA200
# Date
# 2008-10-28   28          1  1044.13  1130.03  1284.87
# 2008-10-13   13          0  1159.42  1208.66  1312.38
#
# [2 rows x 45 columns]

# %%
SP_all_daily[SP_all_daily['return_class']==2].describe()
# Out:
#           S&P_Open    S&P_Close    S&P_Volume    Close_t-1    return(%)  \
# count  2562.000000  2562.000000  2.562000e+03  2562.000000  2562.000000
# mean   1354.423111  1368.707623  2.242541e+09  1352.164992     1.232027
# std     996.682248  1004.800992  1.929841e+09   992.929837     0.880708
# min     204.250000   206.430000  8.629000e+07   204.250000     0.500066
# 25%     645.707500   652.230000  4.206250e+08   645.707500     0.703524
# 50%    1156.255000  1171.110000  1.546125e+09  1155.625000     0.985078
# 75%    1521.575000  1534.687500  3.748255e+09  1519.787500     1.448243
# max    4778.140000  4796.560000  1.008269e+10  4766.180000    11.580036
#
#        return_class    Close_t+1  t+1_return_class   t_3m_Close  t_10y_Close  \
# count        2562.0  2562.000000       2562.000000  2562.000000  2562.000000
# mean            2.0  1368.774715          1.040593     2.923253     4.643795
# std             0.0  1004.491357          0.699690     2.507974     2.323035
# min             2.0   207.390000          0.000000    -0.105000     0.536000
# 25%             2.0   656.145000          1.000000     0.170000     2.657250
# 50%             2.0  1166.905000          1.000000     2.380000     4.434500
# 75%             2.0  1538.580000          2.000000     5.060000     6.394000
# max             2.0  4793.540000          2.000000     9.100000     9.900000
#
#        ...   fx_change%      vo_Open     vo_Close         Year        Month  \
# count  ...  2562.000000  2562.000000  2562.000000  2562.000000  2562.000000
# mean   ...    -0.161062    21.203770    20.407041  2003.960578     6.416472
# std    ...     0.468251     8.611712     7.967483    10.532503     3.460641
# min    ...    -3.510000     9.100000     9.150000  1986.000000     1.000000
# 25%    ...    -0.390000    16.049999    15.530000  1996.000000     3.000000
# 50%    ...    -0.120000    18.750000    18.025000  2003.000000     6.000000
# 75%    ...     0.110000    24.487500    23.425000  2013.000000    10.000000
# max    ...     1.810000    82.690002    75.910004  2022.000000    12.000000
#
#                Day    Dayofweek         MA30         MA50        MA200
# count  2562.000000  2562.000000  2562.000000  2562.000000  2562.000000
# mean     15.517564     1.992584  1356.204649  1354.650699  1329.295933
# std       8.892822     1.398228   995.533792   993.533800   964.198667
# min       1.000000     0.000000   206.020000   200.880000   189.770000
# 25%       8.000000     1.000000   647.940000   647.780000   610.770000
# 50%      15.000000     2.000000  1164.640000  1154.805000  1154.215000
# 75%      23.000000     3.000000  1517.972500  1512.745000  1481.482500
# max      31.000000     4.000000  4681.970000  4678.140000  4496.290000
#
# [8 rows x 45 columns]

# %%
SP_all_daily[SP_all_daily['return_class']==1].describe()
# Out:
#           S&P_Open    S&P_Close    S&P_Volume    Close_t-1    return(%)  \
# count  4545.000000  4545.000000  4.545000e+03  4545.000000  4545.000000
# mean   1338.054717  1338.312077  1.941483e+09  1338.030130     0.019925
# std     992.223627   992.422587  1.662785e+09   992.169672     0.265681
# min     203.490000   204.250000  1.499000e+07   203.490000    -0.498714
# 25%     461.900000   461.840000  2.842300e+08   461.900000    -0.190864
# 50%    1180.520000  1180.590000  1.534600e+09  1180.260000     0.025486
# 75%    1844.710000  1844.860000  3.374170e+09  1845.040000     0.232392
# max    4804.510000  4793.540000  7.946710e+09  4796.560000     0.499571
#
#        return_class    Close_t+1  t+1_return_class   t_3m_Close  t_10y_Close  \
# count        4545.0  4545.000000       4545.000000  4545.000000  4545.000000
# mean            1.0  1338.611272          1.036744     3.002265     4.750726
# std             0.0   992.955686          0.683505     2.478891     2.328985
# min             1.0   205.790000          0.000000    -0.028000     0.515000
# 25%             1.0   462.050000          1.000000     0.290000     2.546000
# 50%             1.0  1178.140000          1.000000     2.950000     4.595000
# 75%             1.0  1844.860000          2.000000     5.030000     6.660000
# max             1.0  4796.560000          2.000000     9.090000     9.710000
#
#        ...   fx_change%      vo_Open     vo_Close         Year        Month  \
# count  ...  4545.000000  4545.000000  4545.000000  4545.000000  4545.000000
# mean   ...    -0.002020    17.149245    17.029553  2003.700110     6.611441
# std    ...     0.391388     5.455785     5.303979    10.792459     3.413861
# min    ...    -2.530000     9.010000     9.140000  1986.000000     1.000000
# 25%    ...    -0.210000    13.120000    13.080000  1994.000000     4.000000
# 50%    ...     0.000000    16.500000    16.350000  2004.000000     7.000000
# 75%    ...     0.220000    19.389999    19.180000  2014.000000    10.000000
# max    ...     2.010000    80.620003    72.000000  2022.000000    12.000000
#
#                Day    Dayofweek         MA30         MA50        MA200
# count  4545.000000  4545.000000  4545.000000  4545.000000  4545.000000
# mean     15.855446     2.025083  1323.766843  1316.571358  1274.961204
# std       8.744818     1.398498   978.975283   973.061713   935.419214
# min       1.000000     0.000000   206.410000   201.310000   189.930000
# 25%       8.000000     1.000000   461.180000   460.070000   458.710000
# 50%      16.000000     2.000000  1167.620000  1154.680000  1139.820000
# 75%      23.000000     3.000000  1816.860000  1812.790000  1718.500000
# max      31.000000     4.000000  4695.010000  4681.010000  4496.730000
#
# [8 rows x 45 columns]

# %%
SP_all_daily[SP_all_daily['return_class']==0].describe()
# Out:
#           S&P_Open    S&P_Close    S&P_Volume    Close_t-1    return(%)  \
# count  2136.000000  2136.000000  2.136000e+03  2136.000000  2136.000000
# mean   1359.010080  1342.428909  2.331891e+09  1361.112477    -1.353221
# std     990.185025   979.813074  2.050402e+09   993.621218     1.072841
# min     205.790000   203.490000  5.720000e+07   205.790000   -20.466926
# 25%     755.882500   742.682500  4.842775e+08   755.882500    -1.620744
# 50%    1171.330000  1154.160000  1.510550e+09  1172.090000    -1.039087
# 75%    1481.262500  1467.285000  3.899522e+09  1481.072500    -0.723678
# max    4787.990000  4700.580000  1.145623e+10  4793.540000    -0.500160
#
#        return_class    Close_t+1  t+1_return_class   t_3m_Close  t_10y_Close  \
# count        2136.0  2136.000000       2136.000000  2136.000000  2136.000000
# mean            0.0  1343.450885          1.072566     2.919237     4.683156
# std             0.0   980.330643          0.780246     2.481334     2.291506
# min             0.0   203.490000          0.000000    -0.058000     0.499000
# 25%             0.0   744.757500          0.000000     0.237250     2.812500
# 50%             0.0  1160.555000          1.000000     2.355000     4.446500
# 75%             0.0  1469.920000          2.000000     5.022500     6.257750
# max             0.0  4712.020000          2.000000     9.040000    10.230000
#
#        ...   fx_change%      vo_Open     vo_Close         Year       Month  \
# count  ...  2136.000000  2136.000000  2136.000000  2136.000000  2136.00000
# mean   ...     0.198717    22.110206    23.001507  2003.906367     6.38015
# std    ...     0.531255     8.931251     9.329613    10.230717     3.39205
# min    ...    -3.700000     9.790000    10.770000  1986.000000     1.00000
# 25%    ...    -0.112500    16.629999    17.240000  1997.000000     3.00000
# 50%    ...     0.140000    19.985000    20.700001  2003.000000     6.00000
# 75%    ...     0.440000    25.552499    26.445000  2012.000000     9.00000
# max    ...     3.340000    79.129997    82.690002  2022.000000    12.00000
#
#                Day    Dayofweek         MA30         MA50        MA200
# count  2136.000000  2136.000000  2136.000000  2136.000000  2136.000000
# mean     15.737360     2.034644  1361.736554  1361.009284  1340.097786
# std       8.583511     1.406148   993.726604   992.335613   967.246061
# min       1.000000     0.000000   205.610000   200.420000   189.620000
# 25%       8.000000     1.000000   759.472500   758.195000   696.962500
# 50%      16.000000     2.000000  1178.485000  1178.130000  1166.560000
# 75%      23.000000     3.000000  1475.265000  1479.755000  1453.800000
# max      31.000000     4.000000  4696.300000  4680.970000  4496.910000
#
# [8 rows x 45 columns]

# %%
#visualize the data
plt.figure(figsize=(15,4))
plt.title('S&P_Close')
plt.xlabel('Date',fontsize=12)
plt.ylabel('S&P_Closing price',fontsize=12)
plt.plot(SP_all_daily['S&P_Close'])
plt.show()
'''
plt.figure(figsize=(15,4))
plt.title('Treausry bill(3M) rate')
plt.plot(SP_all_daily['t_3m_Close'])
plt.show()

plt.figure(figsize=(15,4))
plt.title('Treasury note(10Y) rate')
plt.plot(SP_all_daily['t_10y_Close'])
plt.show()

plt.figure(figsize=(15,4))
plt.title('Consumer Price Index')
plt.plot(SP_all_daily['cpi_Value'])
plt.show()

plt.figure(figsize=(15,4))
plt.title('CPI_MoM%')
plt.plot(SP_all_daily['cpi_MoM%'])
plt.show()

plt.figure(figsize=(15,4))
plt.title('Crude Oil Price')
plt.plot(SP_all_daily['oil_Price'])
plt.show()

plt.figure(figsize=(15,4))
plt.title('umeployment rate')
plt.plot(SP_all_daily['unemp_rate'])
plt.show()
'''
# Out:
# "\nplt.figure(figsize=(15,4))\nplt.title('Treausry bill(3M) rate')\nplt.plot(SP_all_daily['t_3m_Close'])\nplt.show()\n\nplt.figure(figsize=(15,4))\nplt.title('Treasury note(10Y) rate')\nplt.plot(SP_all_daily['t_10y_Close'])\nplt.show()\n\nplt.figure(figsize=(15,4))\nplt.title('Consumer Price Index')\nplt.plot(SP_all_daily['cpi_Value'])\nplt.show()\n\nplt.figure(figsize=(15,4))\nplt.title('CPI_MoM%')\nplt.plot(SP_all_daily['cpi_MoM%'])\nplt.show()\n\nplt.figure(figsize=(15,4))\nplt.title('Crude Oil Price')\nplt.plot(SP_all_daily['oil_Price'])\nplt.show()\n\nplt.figure(figsize=(15,4))\nplt.title('umeployment rate')\nplt.plot(SP_all_daily['unemp_rate'])\nplt.show()\n"

# %% [markdown]
# Box plot

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x='return_class', y='t_3m_Close', data=SP_all_daily)

# %%
ax = sns.boxplot(x='return_class', y='cpi_Value', data=SP_all_daily)

# %%
ax = sns.boxplot(x='return_class', y='cpi_MoM%', data=SP_all_daily)

# %%
ax = sns.boxplot(x='return_class', y='oil_Price', data=SP_all_daily)

# %%
ax = sns.boxplot(x='return_class', y='unemp_rate', data=SP_all_daily)

# %%
# Dailly S&P index return
sns.set(rc={'figure.figsize':(15.7,8.27)})
ax = sns.boxplot(x='Month', y='return(%)', data=SP_all_daily)

# %%
# Daily S&P Index return per year 
sns.set(rc={'figure.figsize':(15.7,8.27)})
ax = sns.boxplot(x='Year', y='return(%)', data=SP_all_daily)

# %%
sns.set(rc={'figure.figsize':(15.7,8.27)})
ax = sns.boxplot(x='Dayofweek', y='return(%)', data=SP_all_daily)

# %% [markdown]
# August 1982 - October 1987 : annualized return 17.6%
# October 19, 1987 market crash a.k.a. Black Monday
# 2000 dot-com bubble burst
# 2008 - 2009 financial crisis

# %% [markdown]
# ## First baseline model

# %% [markdown]
# #### modeling

# %%
# 1. scaling
# 2. building a model (Logistic Regression, Naive Bayes, Decision Tree/Random Forest, SVM, KNN?)

# %%
X = SP_all_daily.drop(['Year','Month','Close_t+1','t+1_return_class'], axis=1)
y = SP_all_daily['t+1_return_class']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[8.11393995e-01, 8.19356117e-01, 3.26850936e-01, ...,
#         8.72333650e-01, 8.51943606e-01, 9.52761481e-01],
#        [8.25290914e-01, 8.16776143e-01, 3.30634617e-01, ...,
#         8.72571921e-01, 8.51021852e-01, 9.53592630e-01],
#        [8.34110697e-01, 8.23560277e-01, 2.77556454e-01, ...,
#         8.72607550e-01, 8.50171518e-01, 9.54437709e-01],
#        ...,
#        [1.60616559e-03, 1.55887021e-03, 7.39605148e-03, ...,
#         1.78146343e-04, 1.98634555e-04, 7.19710073e-05],
#        [1.32579298e-03, 1.60894565e-03, 7.86715426e-03, ...,
#         9.13000007e-05, 1.02665051e-04, 3.48246809e-05],
#        [1.69310283e-03, 1.32808775e-03, 7.33923945e-03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
# Data Splitting 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=27)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import xgboost as xgb
from sklearn.metrics import precision_recall_fscore_support, f1_score, accuracy_score

logreg_clf = LogisticRegression(multi_class = 'multinomial')
LDA_clf = LinearDiscriminantAnalysis()
KNN_clf = KNeighborsClassifier()
NB_clf = GaussianNB()
DT_clf = DecisionTreeClassifier()
SVM_clf = SVC()
xgb_clf = xgb.XGBClassifier()
RF_clf = RandomForestClassifier(max_depth=2, random_state=0)

# %%
# Logistic regression
logreg_clf.fit(X_train,y_train)
y_pred = logreg_clf.predict(X_test)
# Out:
# C:\Users\Irene\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy = accuracy_score(y_test, y_pred)
score = precision_recall_fscore_support(y_test, y_pred, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.5032453483340545
# Test set precision, recall, f-score: (0.46066984562519714, 0.5032453483340545, 0.4248058870039916, None)

# %%
# LDA 
LDA_clf.fit(X_train,y_train)
y_pred_LDA = LDA_clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_LDA)
score = precision_recall_fscore_support(y_test, y_pred_LDA, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.5045434876676763
# Test set precision, recall, f-score: (0.460543178828673, 0.5045434876676763, 0.4323062433977537, None)

# %% [markdown]
# # KNN
# KNN_clf.fit(X_train,y_train)
# y_pred_KNN = KNN_clf.predict(X_test)
# accuracy = accuracy_score(y_test, y_pred_KNN)
# score = precision_recall_fscore_support(y_test, y_pred_KNN, average='weighted')
# print(f'accuracy score: {accuracy}')
# print(f'Test set precision, recall, f-score: {score}')

# %%
# Naive Bayes
NB_clf.fit(X_train,y_train)
y_pred_NB = NB_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_NB)
score = precision_recall_fscore_support(y_test, y_pred_NB, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.48723496321938553
# Test set precision, recall, f-score: (0.444392628131361, 0.48723496321938553, 0.4446233308859175, None)

# %%
# Decision Tree
DT_clf.fit(X_train,y_train)
y_pred_DT = DT_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_DT)
score = precision_recall_fscore_support(y_test, y_pred_DT, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.425356988316746
# Test set precision, recall, f-score: (0.42549670499896064, 0.425356988316746, 0.4254220207450855, None)

# %%
# XGBoost
xgb_clf.fit(X_train,y_train)
y_pred_xgb = xgb_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_xgb)
score = precision_recall_fscore_support(y_test, y_pred_xgb, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.49156209433145825
# Test set precision, recall, f-score: (0.45365275072504363, 0.49156209433145825, 0.45364774734313285, None)

# %%
# Random Forest
RF_clf.fit(X_train,y_train)
y_pred_RF = RF_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_RF)
score = precision_recall_fscore_support(y_test, y_pred_RF, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.48550411077455646
# Test set precision, recall, f-score: (0.349595307579072, 0.48550411077455646, 0.3592091027886412, None)
# C:\Users\Irene\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# SVM
SVM_clf.fit(X_train,y_train)
y_pred_SVM = SVM_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_SVM)
score = precision_recall_fscore_support(y_test, y_pred_SVM, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.4919948074426655
# Test set precision, recall, f-score: (0.4352594113174318, 0.4919948074426655, 0.3808431504509033, None)

# %% [markdown]
# ### Feature selection

# %% [markdown]
# Part 1: Removing Features With Small Variance

# %%
from sklearn.feature_selection import VarianceThreshold

vt = VarianceThreshold(0.1)
X_transformed = vt.fit_transform(X)

# %%
# columns we have selected
# get_support() is method of VarianceThreshold and stores boolean of each variable in the numpy array.
selected_columns = X.columns[vt.get_support()]
# transforming an array back to a data-frame preserves column labels
X_transformed = pd.DataFrame(X_transformed, columns = selected_columns)

# %%
X_transformed
# Out:
#       S&P_Open  S&P_Close    S&P_Volume  Close_t-1  return(%)  return_class  \
# 0      3936.73    3966.85  3.754570e+09    3955.00   0.299621           1.0
# 1      4000.67    3955.00  3.797860e+09    3986.16  -0.781705           0.0
# 2      4041.25    3986.16  3.190580e+09    4030.61  -1.102811           0.0
# 3      4034.58    4030.61  2.963020e+09    4057.66  -0.666640           0.0
# 4      4198.74    4057.66  3.175260e+09    4199.12  -3.368801           0.0
# ...        ...        ...           ...        ...        ...           ...
# 9238    213.80     207.97  1.803000e+08     213.80  -2.726848           0.0
# 9239    210.65     213.80  1.530000e+08     210.65   1.495371           2.0
# 9240    210.88     210.65  9.961000e+07     210.88  -0.109067           1.0
# 9241    209.59     210.88  1.050000e+08     209.59   0.615487           2.0
# 9242    211.28     209.59  9.896000e+07     211.28  -0.799886           0.0
#
#       t_3m_Close  t_10y_Close  cpi_Value  oil_Price  ...      Nk_Close  \
# 0          2.860        3.133    295.271      97.40  ...  27661.470703
# 1          2.860        3.133    295.271      97.40  ...  28091.529297
# 2          2.873        3.110    295.271      97.40  ...  28195.580078
# 3          2.798        3.110    295.271      97.40  ...  27878.960938
# 4          2.755        3.035    295.271      93.63  ...  28641.380859
# ...          ...          ...        ...        ...  ...           ...
# 9238       7.170        9.130    109.000      25.87  ...  13056.419922
# 9239       7.030        8.940    109.000      25.85  ...  12991.240234
# 9240       7.060        9.070    109.000      26.53  ...  13053.790039
# 9241       7.070        9.050    109.000      26.00  ...  13053.790039
# 9242       7.100        9.040    109.000      25.56  ...  13053.790039
#
#        Nk_Volume  fx_change%    vo_Open   vo_Close   Day  Dayofweek     MA30  \
# 0     68900000.0        0.19  26.879999  25.559999   1.0        3.0  4122.99
# 1     86200000.0        0.27  25.860001  25.870001  31.0        2.0  4124.06
# 2     60700000.0        0.62  25.750000  26.209999  30.0        1.0  4124.22
# 3     64100000.0       -0.17  26.860001  26.209999  29.0        0.0  4122.57
# 4     49100000.0        0.84  22.070000  25.559999  26.0        4.0  4115.91
# ...          ...         ...        ...        ...   ...        ...      ...
# 9238         0.0        0.14  17.240000  17.240000   8.0        2.0   207.03
# 9239         0.0       -0.50  17.240000  17.240000   7.0        1.0   206.82
# 9240         0.0        0.21  17.240000  17.240000   6.0        0.0   206.41
# 9241         0.0        0.15  17.240000  17.240000   3.0        4.0   206.02
# 9242         0.0        0.18  17.240000  17.240000   2.0        3.0   205.61
#
#          MA50    MA200
# 0     4017.63  4293.44
# 1     4013.50  4297.02
# 2     4009.69  4300.66
# 3     4003.46  4303.97
# 4     3996.19  4307.05
# ...       ...      ...
# 9238   202.22   190.25
# 9239   201.81   190.10
# 9240   201.31   189.93
# 9241   200.88   189.77
# 9242   200.42   189.62
#
# [9243 rows x 38 columns]

# %%
X
# Out:
#             S&P_Open  S&P_Close    S&P_Volume  Close_t-1  return(%)  \
# Date
# 2022-09-01   3936.73    3966.85  3.754570e+09    3955.00   0.299621
# 2022-08-31   4000.67    3955.00  3.797860e+09    3986.16  -0.781705
# 2022-08-30   4041.25    3986.16  3.190580e+09    4030.61  -1.102811
# 2022-08-29   4034.58    4030.61  2.963020e+09    4057.66  -0.666640
# 2022-08-26   4198.74    4057.66  3.175260e+09    4199.12  -3.368801
# ...              ...        ...           ...        ...        ...
# 1986-01-08    213.80     207.97  1.803000e+08     213.80  -2.726848
# 1986-01-07    210.65     213.80  1.530000e+08     210.65   1.495371
# 1986-01-06    210.88     210.65  9.961000e+07     210.88  -0.109067
# 1986-01-03    209.59     210.88  1.050000e+08     209.59   0.615487
# 1986-01-02    211.28     209.59  9.896000e+07     211.28  -0.799886
#
#             return_class  t_3m_Close  t_10y_Close  cpi_Value  cpi_MoM%  ...  \
# Date                                                                    ...
# 2022-09-01             1       2.860        3.133    295.271       0.0  ...
# 2022-08-31             0       2.860        3.133    295.271       0.0  ...
# 2022-08-30             0       2.873        3.110    295.271       0.0  ...
# 2022-08-29             0       2.798        3.110    295.271       0.0  ...
# 2022-08-26             0       2.755        3.035    295.271       0.0  ...
# ...                  ...         ...          ...        ...       ...  ...
# 1986-01-08             0       7.170        9.130    109.000       0.5  ...
# 1986-01-07             2       7.030        8.940    109.000       0.5  ...
# 1986-01-06             1       7.060        9.070    109.000       0.5  ...
# 1986-01-03             2       7.070        9.050    109.000       0.5  ...
# 1986-01-02             0       7.100        9.040    109.000       0.5  ...
#
#              Nk_Volume  fx_Price  fx_change%    vo_Open   vo_Close  Day  \
# Date
# 2022-09-01  68900000.0    1.3152        0.19  26.879999  25.559999    1
# 2022-08-31  86200000.0    1.3127        0.27  25.860001  25.870001   31
# 2022-08-30  60700000.0    1.3092        0.62  25.750000  26.209999   30
# 2022-08-29  64100000.0    1.3011       -0.17  26.860001  26.209999   29
# 2022-08-26  49100000.0    1.3033        0.84  22.070000  25.559999   26
# ...                ...       ...         ...        ...        ...  ...
# 1986-01-08         0.0    1.4010        0.14  17.240000  17.240000    8
# 1986-01-07         0.0    1.3991       -0.50  17.240000  17.240000    7
# 1986-01-06         0.0    1.4061        0.21  17.240000  17.240000    6
# 1986-01-03         0.0    1.4031        0.15  17.240000  17.240000    3
# 1986-01-02         0.0    1.4010        0.18  17.240000  17.240000    2
#
#             Dayofweek     MA30     MA50    MA200
# Date
# 2022-09-01          3  4122.99  4017.63  4293.44
# 2022-08-31          2  4124.06  4013.50  4297.02
# 2022-08-30          1  4124.22  4009.69  4300.66
# 2022-08-29          0  4122.57  4003.46  4303.97
# 2022-08-26          4  4115.91  3996.19  4307.05
# ...               ...      ...      ...      ...
# 1986-01-08          2   207.03   202.22   190.25
# 1986-01-07          1   206.82   201.81   190.10
# 1986-01-06          0   206.41   201.31   189.93
# 1986-01-03          4   206.02   200.88   189.77
# 1986-01-02          3   205.61   200.42   189.62
#
# [9243 rows x 41 columns]

# %% [markdown]
# Part 2: Removing Correlated Features

# %%
# step 1
X_corr = X_transformed.corr().abs()

# step 2
indices = np.where(X_corr > 0.9) 
indices = [(X_corr.index[x], X_corr.columns[y]) 
for x, y in zip(*indices)
    if x != y and x < y]

# step 3
for idx in indices: #each pair
    try:
        X_transformed.drop(idx[1], axis = 1, inplace=True)
    except KeyError:
        pass

# %%
print(indices)
# Out:
# [('S&P_Open', 'S&P_Close'), ('S&P_Open', 'Close_t-1'), ('S&P_Open', 'Div_Ratio'), ('S&P_Open', 'R_Open'), ('S&P_Open', 'R_Close'), ('S&P_Open', 'Nas_Open'), ('S&P_Open', 'Nas_Close'), ('S&P_Open', 'MA30'), ('S&P_Open', 'MA50'), ('S&P_Open', 'MA200'), ('S&P_Close', 'Close_t-1'), ('S&P_Close', 'Div_Ratio'), ('S&P_Close', 'R_Open'), ('S&P_Close', 'R_Close'), ('S&P_Close', 'Nas_Open'), ('S&P_Close', 'Nas_Close'), ('S&P_Close', 'MA30'), ('S&P_Close', 'MA50'), ('S&P_Close', 'MA200'), ('S&P_Volume', 'R_Volume'), ('Close_t-1', 'Div_Ratio'), ('Close_t-1', 'R_Open'), ('Close_t-1', 'R_Close'), ('Close_t-1', 'Nas_Open'), ('Close_t-1', 'Nas_Close'), ('Close_t-1', 'MA30'), ('Close_t-1', 'MA50'), ('Close_t-1', 'MA200'), ('t_3m_Close', 't_10y_Close'), ('t_10y_Close', 'cpi_Value'), ('cpi_Value', 'R_Open'), ('cpi_Value', 'R_Close'), ('Div_Ratio', 'R_Open'), ('Div_Ratio', 'R_Close'), ('Div_Ratio', 'Nas_Open'), ('Div_Ratio', 'Nas_Close'), ('Div_Ratio', 'MA30'), ('Div_Ratio', 'MA50'), ('Div_Ratio', 'MA200'), ('R_Open', 'R_Close'), ('R_Open', 'Nas_Open'), ('R_Open', 'Nas_Close'), ('R_Open', 'MA30'), ('R_Open', 'MA50'), ('R_Open', 'MA200'), ('R_Close', 'Nas_Open'), ('R_Close', 'Nas_Close'), ('R_Close', 'MA30'), ('R_Close', 'MA50'), ('R_Close', 'MA200'), ('G_Open', 'G_Close'), ('G_Open', 'GF_Open'), ('G_Open', 'GF_Close'), ('G_Close', 'GF_Open'), ('G_Close', 'GF_Close'), ('G_Volume', 'GF_Volume'), ('GF_Open', 'GF_Close'), ('Nas_Open', 'Nas_Close'), ('Nas_Open', 'MA30'), ('Nas_Open', 'MA50'), ('Nas_Open', 'MA200'), ('Nas_Close', 'MA30'), ('Nas_Close', 'MA50'), ('Nas_Close', 'MA200'), ('Nk_Open', 'Nk_Close'), ('vo_Open', 'vo_Close'), ('MA30', 'MA50'), ('MA30', 'MA200'), ('MA50', 'MA200')]

# %%
X_transformed
# Out:
#       S&P_Open    S&P_Volume  return(%)  return_class  t_3m_Close  oil_Price  \
# 0      3936.73  3.754570e+09   0.299621           1.0       2.860      97.40
# 1      4000.67  3.797860e+09  -0.781705           0.0       2.860      97.40
# 2      4041.25  3.190580e+09  -1.102811           0.0       2.873      97.40
# 3      4034.58  2.963020e+09  -0.666640           0.0       2.798      97.40
# 4      4198.74  3.175260e+09  -3.368801           0.0       2.755      93.63
# ...        ...           ...        ...           ...         ...        ...
# 9238    213.80  1.803000e+08  -2.726848           0.0       7.170      25.87
# 9239    210.65  1.530000e+08   1.495371           2.0       7.030      25.85
# 9240    210.88  9.961000e+07  -0.109067           1.0       7.060      26.53
# 9241    209.59  1.050000e+08   0.615487           2.0       7.070      26.00
# 9242    211.28  9.896000e+07  -0.799886           0.0       7.100      25.56
#
#       unemp_rate  PE_Ratio  EY_Ratio  CS_Index  G_Open  G_Volume  \
# 0            3.5     20.04      4.99      50.0  1718.3     385.0
# 1            3.5     19.98      5.00      50.0  1718.3     385.0
# 2            3.5     20.93      4.78      50.0  1736.4     385.0
# 3            3.5     20.93      4.78      50.0  1732.4     950.0
# 4            3.5     20.93      4.78      50.0  1754.0     202.0
# ...          ...       ...       ...       ...     ...       ...
# 9238         7.0     13.33      7.50      93.9   273.9       2.0
# 9239         7.0     13.33      7.50      93.9   273.9       2.0
# 9240         7.0     13.33      7.50      93.9   273.9       2.0
# 9241         7.0     13.33      7.50      93.9   273.9       2.0
# 9242         7.0     13.33      7.50      93.9   273.9       2.0
#
#         Nas_Volume       Nk_Open   Nk_Volume  fx_change%    vo_Open   Day  \
# 0     4.053100e+08  27797.000000  68900000.0        0.19  26.879999   1.0
# 1     4.911500e+09  27928.089844  86200000.0        0.27  25.860001  31.0
# 2     4.630720e+09  28086.720703  60700000.0        0.62  25.750000  30.0
# 3     4.183740e+09  28161.060547  64100000.0       -0.17  26.860001  29.0
# 4     4.510480e+09  28639.470703  49100000.0        0.84  22.070000  26.0
# ...            ...           ...         ...         ...        ...   ...
# 9238  1.400000e+08  13056.419922         0.0        0.14  17.240000   8.0
# 9239  1.275000e+08  12991.240234         0.0       -0.50  17.240000   7.0
# 9240  9.924000e+07  13053.790039         0.0        0.21  17.240000   6.0
# 9241  8.918000e+07  13053.790039         0.0        0.15  17.240000   3.0
# 9242  7.581000e+07  13053.790039         0.0        0.18  17.240000   2.0
#
#       Dayofweek
# 0           3.0
# 1           2.0
# 2           1.0
# 3           0.0
# 4           4.0
# ...         ...
# 9238        2.0
# 9239        1.0
# 9240        0.0
# 9241        4.0
# 9242        3.0
#
# [9243 rows x 19 columns]

# %% [markdown]
# Part 3: Forward Regression

# %% [markdown]
# from sklearn.feature_selection import f_regression, SelectKBest
# skb = SelectKBest(f_regression, k=8)
# X_transformed = skb.fit_transform(X, y)

# %% [markdown]
# # this will give us the position of top 10 columns
# skb.get_support()
# # column names
# X.columns[skb.get_support()]
# X_transformed = pd.DataFrame(X_transformed,columns=X.columns[skb.get_support()])

# %% [markdown]
# X

# %% [markdown]
# ### Second modeling

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=27)

# %%
logreg_clf = LogisticRegression(multi_class = 'multinomial')
LDA_clf = LinearDiscriminantAnalysis() # Similar to PCA, to separate it with PCA 
KNN_clf = KNeighborsClassifier()
NB_clf = GaussianNB()
DT_clf = DecisionTreeClassifier()
SVM_clf = SVC()
xgb_clf = xgb.XGBClassifier()
RF_clf = RandomForestClassifier(max_depth=2, random_state=0)

# %%
# Logistic regression
logreg_clf.fit(X_train,y_train)
y_pred = logreg_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
score = precision_recall_fscore_support(y_test, y_pred, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.5032453483340545
# Test set precision, recall, f-score: (0.46066984562519714, 0.5032453483340545, 0.4248058870039916, None)
# C:\Users\Irene\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# LDA 
LDA_clf.fit(X_train,y_train)
y_pred_LDA = LDA_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_LDA)
score = precision_recall_fscore_support(y_test, y_pred_LDA, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.5045434876676763
# Test set precision, recall, f-score: (0.460543178828673, 0.5045434876676763, 0.4323062433977537, None)

# %% [markdown]
# # KNN
# KNN_clf.fit(X_train,y_train)
# y_pred_KNN = KNN_clf.predict(X_test)
# accuracy = accuracy_score(y_test, y_pred_KNN)
# score = precision_recall_fscore_support(y_test, y_pred_KNN, average='weighted')
# print(f'accuracy score: {accuracy}')
# print(f'Test set precision, recall, f-score: {score}')

# %%
# Naive Bayes
NB_clf.fit(X_train,y_train)
y_pred_NB = NB_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_NB)
score = precision_recall_fscore_support(y_test, y_pred_NB, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.48723496321938553
# Test set precision, recall, f-score: (0.444392628131361, 0.48723496321938553, 0.4446233308859175, None)

# %%
# Decision Tree
DT_clf.fit(X_train,y_train)
y_pred_DT = DT_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_DT)
score = precision_recall_fscore_support(y_test, y_pred_DT, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.41151016875811336
# Test set precision, recall, f-score: (0.4120010055498417, 0.41151016875811336, 0.41175340726266635, None)

# %%
# XGBoost
xgb_clf.fit(X_train,y_train)
y_pred_xgb = xgb_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_xgb)
score = precision_recall_fscore_support(y_test, y_pred_xgb, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.49156209433145825
# Test set precision, recall, f-score: (0.45365275072504363, 0.49156209433145825, 0.45364774734313285, None)

# %%
# Random Forest
RF_clf.fit(X_train,y_train)
y_pred_RF = RF_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_RF)
score = precision_recall_fscore_support(y_test, y_pred_RF, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.48550411077455646
# Test set precision, recall, f-score: (0.349595307579072, 0.48550411077455646, 0.3592091027886412, None)
# C:\Users\Irene\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# SVM
SVM_clf.fit(X_train,y_train)
y_pred_SVM = SVM_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_SVM)
score = precision_recall_fscore_support(y_test, y_pred_SVM, average='weighted')
print(f'accuracy score: {accuracy}')
print(f'Test set precision, recall, f-score: {score}')
# Out:
# accuracy score: 0.4919948074426655
# Test set precision, recall, f-score: (0.4352594113174318, 0.4919948074426655, 0.3808431504509033, None)
